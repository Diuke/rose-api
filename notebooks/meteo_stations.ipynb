# %%
import pandas as pd
import datetime as dt
import numpy as np
import requests
import json
import math
# Out:
# C:\Users\juan-\AppData\Local\Temp\ipykernel_19924\2784272662.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
stations_df = pd.read_csv("Stazioni_Meteorologiche.csv")
stations_df
# Out:
#       IdSensore           Tipologia Unità DiMisura  IdStazione  \
# 0         22006    Umidità Relativa              %        1890
# 1         22007     Direzione Vento              °        1890
# 2         22003         Temperatura             °C        1890
# 3         22009      Velocità Vento            m/s        1890
# 4         17612        Altezza Neve             cm        1545
# ...         ...                 ...            ...         ...
# 1243      10787      Velocità Vento            m/s        1266
# 1244      19024  Radiazione Globale           W/m²        1422
# 1245       7048      Velocità Vento            m/s         695
# 1246       6990  Radiazione Globale           W/m²         679
# 1247       2595         Temperatura             °C         205
#
#                              NomeStazione  Quota Provincia   DataStart  \
# 0     Tavernole sul Mella Monte Guglielmo   1790        BS  14/10/2019
# ...

# %%
#stations_df.loc[stations_df['IdSensore'] == 20574]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Comune'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
# ...
